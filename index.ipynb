# %% [markdown]
# # Join Statements

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this lab, you'll practice your knowledge on Join statements.

# %% [markdown]
# ## Objectives

# %% [markdown]
# You will be able to:
# - Write queries that make use of various types of Joins
# - Join tables using foreign keys

# %% [markdown]
# ## CRM Schema
#
# In almost all cases, rather then just working with a single table we will typically need data from multiple tables.
# Doing this requires the use of **joins ** using shared columns from the two tables.
#
# In this lab, we'll use the same Customer Relationship Management (CRM) database we used in our lecture before!
# <img src='Database-Schema.png' width=550>

# %% [markdown]
# ## Connecting to the Database
# Import the necessary packages and connect to the database **data.sqlite**.

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('data.sqlite', detect_types=sqlite3.PARSE_COLNAMES)
cur = conn.cursor()

# %% [markdown]
# ## Display the names of all the employees in Boston.

# %%
#Your code here

# %% [markdown]
# ## Do any offices have no employees?

# %%
#Your code here

# %% [markdown]
# ## Write 3 Questions of your own and answer them

# %%
# Answers will vary

# %%
# Your code here

# %%
# Your code here

# %%
# Your code here

# %% [markdown]
# ## Level Up: Display the names of each product each employee has sold.

# %%
cur.execute("""select firstName, lastName, productName,
            employeeNumber from employees e
            join customers c on e.employeeNumber = c.salesRepEmployeeNumber
            join orders o on c.customerNumber = o.customerNumber
            join orderDetails od on o.orderNumber = od.orderNumber
            join products p on od.productCode = p.productCode;""")
cur.fetchall()
# Out:
# [('Leslie', 'Jennings', '1958 Setra Bus', '1165'),
#  ('Leslie', 'Jennings', '1940 Ford Pickup Truck', '1165'),
#  ('Leslie', 'Jennings', '1939 Cadillac Limousine', '1165'),
#  ('Leslie', 'Jennings', '1996 Peterbilt 379 Stake Bed with Outrigger', '1165'),
#  ('Leslie', 'Jennings', '1968 Ford Mustang', '1165'),
#  ('Leslie', 'Jennings', '1968 Dodge Charger', '1165'),
#  ('Leslie', 'Jennings', '1970 Plymouth Hemi Cuda', '1165'),
#  ('Leslie', 'Jennings', '1969 Dodge Charger', '1165'),
#  ('Leslie', 'Jennings', '1948 Porsche 356-A Roadster', '1165'),
#  ('Leslie', 'Jennings', '1969 Dodge Super Bee', '1165'),
#  ('Leslie', 'Jennings', '1976 Ford Gran Torino', '1165'),
#  ('Leslie', 'Jennings', '1957 Vespa GS150', '1165'),
#  ('Leslie', 'Jennings', '1957 Corvette Convertible', '1165'),
#  ('Leslie', 'Jennings', '1982 Ducati 900 Monster', '1165'),
#  ('Leslie', 'Jennings', '1982 Lamborghini Diablo', '1165'),
#  ('Leslie', 'Jennings', '1971 Alpine Renault 1600s', '1165'),
# ...

# %% [markdown]
# ## Level Up: Display the Number of Products each Employee Has sold

# %%
cur.execute("""select firstName, lastName, count(productName),
            employeeNumber from employees e
            join customers c on e.employeeNumber = c.salesRepEmployeeNumber
            join orders o on c.customerNumber = o.customerNumber
            join orderDetails od on o.orderNumber = od.orderNumber
            join products p on od.productCode = p.productCode
            group by e.employeeNumber;""").fetchall()
# Out:
# [('Leslie', 'Jennings', 331, '1165'),
#  ('Leslie', 'Thompson', 114, '1166'),
#  ('Julie', 'Firrelli', 124, '1188'),
#  ('Steve', 'Patterson', 152, '1216'),
#  ('Foon Yue', 'Tseng', 142, '1286'),
#  ('George', 'Vanauf', 211, '1323'),
#  ('Loui', 'Bondur', 177, '1337'),
#  ('Gerard', 'Hernandez', 396, '1370'),
#  ('Pamela', 'Castillo', 272, '1401'),
#  ('Larry', 'Bott', 236, '1501'),
#  ('Barry', 'Jones', 220, '1504'),
#  ('Andy', 'Fixter', 185, '1611'),
#  ('Peter', 'Marsh', 185, '1612'),
#  ('Mami', 'Nishi', 137, '1621'),
#  ('Martin', 'Gerard', 114, '1702')]

# %%
cur.execute("""select firstName, lastName, productName, count(productName)
            from employees e
            join customers c on e.employeeNumber = c.salesRepEmployeeNumber
            join orders o on c.customerNumber = o.customerNumber
            join orderDetails od on o.orderNumber = od.orderNumber
            join products p on od.productCode = p.productCode
            group by p.productCode,e.employeeNumber;""").fetchall()
# Out:
# [('Leslie', 'Jennings', '1969 Harley Davidson Ultimate Chopper', 3),
#  ('Leslie', 'Thompson', '1969 Harley Davidson Ultimate Chopper', 1),
#  ('Steve', 'Patterson', '1969 Harley Davidson Ultimate Chopper', 3),
#  ('Foon Yue', 'Tseng', '1969 Harley Davidson Ultimate Chopper', 1),
#  ('George', 'Vanauf', '1969 Harley Davidson Ultimate Chopper', 4),
#  ('Loui', 'Bondur', '1969 Harley Davidson Ultimate Chopper', 3),
#  ('Gerard', 'Hernandez', '1969 Harley Davidson Ultimate Chopper', 4),
#  ('Pamela', 'Castillo', '1969 Harley Davidson Ultimate Chopper', 1),
#  ('Larry', 'Bott', '1969 Harley Davidson Ultimate Chopper', 2),
#  ('Barry', 'Jones', '1969 Harley Davidson Ultimate Chopper', 2),
#  ('Andy', 'Fixter', '1969 Harley Davidson Ultimate Chopper', 2),
#  ('Peter', 'Marsh', '1969 Harley Davidson Ultimate Chopper', 2),
#  ('Leslie', 'Jennings', '1952 Alpine Renault 1300', 5),
#  ('Leslie', 'Thompson', '1952 Alpine Renault 1300', 1),
# ...

# %%
cur.execute("""select productName, count(productCode)
            ;""").fetchall()

# %% [markdown]
# ## Summary

# %% [markdown]
# Congrats! You now know how to use Join statements, along with leveraging your foreign keys knowledge!
